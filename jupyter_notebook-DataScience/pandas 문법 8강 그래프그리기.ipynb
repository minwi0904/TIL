# %% [markdown]
# df.loc[조건, '열이름'] = '바꿀값' # 이거 아주 좋아

# %% [markdown]
# 8강 그래프그리기 챕터

# %% [markdown]
# 선그래프

# %%
# %matplotlib inline

import pandas as pd

# %%
df = pd.read_csv('broadcast.csv', index_col = 0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df.plot() # 판다스 능력!

# %%
df.plot(y='KBS')

# %%
df.plot(y=['KBS', 'JTBC'])

# %%
df[['KBS', 'JTBC']]
# Out:
#          KBS   JTBC
# 2011  35.951  7.380
# 2012  36.163  7.878
# 2013  31.989  7.810
# 2014  31.210  7.490
# 2015  27.777  7.267
# 2016  27.583  7.727
# 2017  26.890  9.453

# %%
df[['KBS', 'JTBC']].plot()

# %%
df['KBS']
# Out:
# 2011    35.951
# 2012    36.163
# 2013    31.989
# 2014    31.210
# 2015    27.777
# 2016    27.583
# 2017    26.890
# Name: KBS, dtype: float64

# %%
df['KBS'].plot()

# %%
sport = pd.read_csv('sports.csv', index_col=0)
sport
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
sport.plot()

# %%
sport.plot(kind='bar')

# %%
sport.plot(kind='barh')

# %%
sport.plot(kind='bar', stacked='True')

# %%
sport['Female']
# Out:
# Swimming      178
# Baseball      289
# Basketball     97
# Golf          232
# Soccer        109
# Bowling       129
# Name: Female, dtype: int64

# %%
sport['Female'].plot(kind='bar')

# %%
broadcast = pd.read_csv('broadcast.csv', index_col=0)
broadcast
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
broadcast.loc[2017]
# Out:
# KBS          26.890
# MBC          12.465
# SBS           8.661
# TV CHOSUN     8.886
# JTBC          9.453
# Channel A     6.056
# MBN           5.215
# Name: 2017, dtype: float64

# %%
broadcast.loc[2017].plot(kind='pie')

# %%
body = pd.read_csv('body.csv', index_col=0)
body.head(10)
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# 6        175.4    72.7
# 7        181.5    87.9
# 8        174.2    64.5
# 9        176.4    57.5
# 10       175.8    66.4

# %%
body.plot(kind='hist', y='Height') # 히스토그램은 범위친구들을 묶어서 나눠줘 범위 디폴트는 10

# %%
body.plot(kind='hist', y='Height', bins=15)

# %%
body.plot(kind='hist', y='Height', bins=200) # 앤 별로라서 적당한 범위나누는것을 잘 찾아야함

# %%
exam = pd.read_csv('exam.csv', index_col=0)
exam.head()
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# female               completed          69             90             88
# female                    none          90             95             93
# male                      none          47             57             44
# male                      none          76             78             75

# %%
exam['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
exam.plot(kind='box', y='math score')

# %%
exam.plot(kind='box', y=['math score', 'reading score', 'writing score'])

# %%
exam.plot(kind='scatter', x='math score', y='reading score')

# %%
exam.plot(kind='scatter', x='math score', y='writing score')

# %%
exam.plot(kind='scatter', x='reading score', y='writing score')

# %%
world_index = pd.read_csv('world_indexes.csv', index_col=0)
world_index.head()
# Out:
#              Human Development Index HDI-2014  Gini coefficient 2005-2013  \
# Id
# Norway                               0.943877                       26.83
# Australia                            0.934958                       34.01
# Switzerland                          0.929613                       32.35
# Denmark                              0.923328                       26.88
# Netherlands                          0.921794                       28.87
#
#              Adolescent birth rate 15-19 per 100k 20102015  \
# Id
# Norway                                               7.834
# Australia                                           12.059
# Switzerland                                          1.900
# Denmark                                              5.101
# Netherlands                                          6.165
#
#              Birth registration funder age 5 2005-2013  \
# Id
# Norway                                           100.0
# ...

# %%
world_index.plot(kind='scatter', x='Life expectancy at birth- years', y='Internet users percentage of population 2014')

# %%
world_index.plot(kind='scatter', x='Life expectancy at birth- years', y='Carbon dioxide emissionsAverage annual growth')

# %%
world_index.plot(kind='scatter', x='Life expectancy at birth- years', y='Forest area percentage of total land area 2012')

# %%
world_index.plot(kind='scatter', x='Forest area percentage of total land area 2012', y='Carbon dioxide emissionsAverage annual growth')

# %%
world_index.plot(kind='scatter', x='Internet users percentage of population 2014', y='Forest area percentage of total land area 2012')
